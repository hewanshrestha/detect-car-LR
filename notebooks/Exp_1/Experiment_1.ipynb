# %% [markdown]
# <a href="https://colab.research.google.com/github/akansh12/detect-car-LR/blob/main/notebooks/Experiment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget "https://gdo152.llnl.gov/cowc/download/cowc-m/_new_datasets/DetectionPatches_512x512_ALL_No-Overlap.zip"
# Out:
# --2023-06-01 13:19:54--  https://gdo152.llnl.gov/cowc/download/cowc-m/_new_datasets/DetectionPatches_512x512_ALL_No-Overlap.zip
# Resolving gdo152.llnl.gov (gdo152.llnl.gov)... 192.12.137.155
# Connecting to gdo152.llnl.gov (gdo152.llnl.gov)|192.12.137.155|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1538955558 (1.4G) [application/zip]
# Saving to: ‘DetectionPatches_512x512_ALL_No-Overlap.zip’
#
# DetectionPatches_51 100%[===================>]   1.43G  53.4MB/s    in 28s
#
# 2023-06-01 13:20:23 (52.2 MB/s) - ‘DetectionPatches_512x512_ALL_No-Overlap.zip’ saved [1538955558/1538955558]

# %%
# !unzip /content/DetectionPatches_512x512_ALL_No-Overlap.zip

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
from glob import glob

# %%
a = glob("/content/DetectionPatches_512x512_ALL_No-Overlap/Toronto_ISPRS/Toronto_03747.18.2.**")

# %%
print(a)
# Out:
# ['/content/DetectionPatches_512x512_ALL_No-Overlap/Toronto_ISPRS/Toronto_03747.18.2.jpg', '/content/DetectionPatches_512x512_ALL_No-Overlap/Toronto_ISPRS/Toronto_03747.18.2.check.jpg', '/content/DetectionPatches_512x512_ALL_No-Overlap/Toronto_ISPRS/Toronto_03747.18.2.txt']

# %%
plt.imshow(plt.imread(a[1]))

# %%
plt.imshow(plt.imread(a[0]))

# %%
os.listdir("/content/DetectionPatches_512x512_ALL_No-Overlap/Toronto_ISPRS/")
# Out:
# ['Toronto_03553.10.13.check.jpg',
#  'Toronto_03747.9.9.txt',
#  'Toronto_03747.6.10.check.jpg',
#  'Toronto_03553.8.10.jpg',
#  'Toronto_03747.16.6.check.jpg',
#  'Toronto_03559.10.0.check.jpg',
#  'Toronto_03553.16.6.check.jpg',
#  'Toronto_03553.20.4.jpg',
#  'Toronto_03747.1.8.check.jpg',
#  'Toronto_03553.12.11.txt',
#  'Toronto_03559.11.5.txt',
#  'Toronto_03553.16.13.txt',
#  'Toronto_03553.21.11.txt',
#  'Toronto_03559.8.4.txt',
#  'Toronto_03559.21.13.txt',
#  'Toronto_03553.12.5.check.jpg',
#  'Toronto_03559.10.6.jpg',
#  'Toronto_03559.12.1.jpg',
#  'Toronto_03747.2.1.jpg',
#  'Toronto_03747.20.10.jpg',
#  'Toronto_03553.7.5.jpg',
#  'Toronto_03559.11.3.check.jpg',
#  'Toronto_03747.1.11.txt',
#  'Toronto_03553.2.0.jpg',
#  'Toronto_03747.0.4.check.jpg',
#  'Toronto_03747.1.2.check.jpg',
#  'Toronto_03747.15.3.jpg',
#  'Toronto_03559.6.1.jpg',
#  'Toronto_03559.13.12.txt',
#  'Toronto_03747.5.9.check.jpg',
#  'Toronto_03553.9.10.txt',
#  'Toronto_03559.3.12.txt',
# ...

# %%
# !pip install roboflow

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="5ytAWfVLS79flUxDMPwf")
project = rf.workspace().project("vehicle-detection-gr77r")
model = project.version(1).model

# infer on a local image
print(model.predict(a[0], confidence=40, overlap=30).json())

# visualize your prediction
model.predict(a[0], confidence=40, overlap=30).save("prediction.jpg")

# infer on an image hosted elsewhere
# print(model.predict("URL_OF_YOUR_IMAGE", hosted=True, confidence=40, overlap=30).json())
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# {'predictions': [{'x': 376, 'y': 156, 'width': 60, 'height': 52, 'confidence': 0.5258857607841492, 'class': '1', 'image_path': '/content/DetectionPatches_512x512_ALL_No-Overlap/Toronto_ISPRS/Toronto_03747.18.2.jpg', 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': '512', 'height': '512'}}
